# %%
import numpy as np

# %%
def Factorial(n=0):
    
    fact = 1
    i = 1
    
    if n == 0:
        return fact
    else:
        
        while i <= n:
            fact *= i
            i += 1
        
        return fact

# %%
Factorial(10)
# Out:
# 3628800

# %%
def Variaciones(n=0,r=0):
    
    fact = 1
    i = n
    
    if n==0:
        return fact
    else:
        
        while i > n-r:
          #  print(i)
            fact *= i
            i -= 1
            
        return fact

# %%
Variaciones(6,3)
# Out:
# 120

# %%
def Combinatoria(n,m):
    
    V = Variaciones(n,m)
    r = Factorial(m)
    return int(V/r)

# %%
Combinatoria(22,11)
# Out:
# 705432
